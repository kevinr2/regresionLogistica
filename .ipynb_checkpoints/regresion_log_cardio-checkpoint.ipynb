# %% [markdown]
# ## ejercicio regresion logistica

# %%
#librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./framingham_heart_disease.csv')

# %%
data.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %%
#obtener datos de interes
data[['BMI','currentSmoker']].head()
# Out:
#      BMI  currentSmoker
# 0  26.97              0
# 1  28.73              0
# 2  25.34              1
# 3  28.58              1
# 4  23.10              1

# %%
data[['BMI','currentSmoker']].plot.scatter(x='BMI',y='currentSmoker')
# Out:
# <Axes: xlabel='BMI', ylabel='TenYearCHD'>

# %%
w = 0.05
b = -3.04

# %%
x = np.linspace(0,data['BMI'].max(),100)
y= 1/(1+np.exp(-(w*x+b)))

#grafica de la recta
data.plot.scatter(x='BMI',y='currentSmoker')
plt.plot(x,y,'-r')
plt.ylim(0,data['currentSmoker'].max()*1.1)
#plt.grid()
plt.show()

# %%
data['id'] = 1/(1+np.exp(-(data['BMI']*w+b)))

# calculo de la funcion de error
data['loss_xi'] = -data['TenYearCHD']*np.log(data['id'])-(1-data['TenYearCHD'])*np.log(1-data['id'])
cost_j = data['loss_xi'].mean()
cost_j
# Out:
# 0.44008411803436526

# %%
array = np.mgrid[0.05:0.15:0.01, -4:-3:0.01].reshape(2,-1).T
df = pd.DataFrame(data = array, 
                  columns = ['w','b'])

# round para solventar problema con muchos decimales
df['w'] = np.round(df['w'], 6)
df['b'] = np.round(df['b'], 6)

# %%
def sum_error_df(df):
    data['id'] = 1/(1+np.exp(-(data['BMI']*df['w']+df['b'])))
    data['loss_xi'] = -data['TenYearCHD']*np.log(data['id'])-(1-data['TenYearCHD'])*np.log(1-data['id'])
    j_cost = data['loss_xi'].mean()
    return(j_cost)

# %%
df['error'] = df.apply(sum_error_df, axis=1)

# %%
df.sort_values(by=['error']).head()
# Out:
#        w     b     error
# 96  0.05 -3.04  0.420476
# 97  0.05 -3.03  0.420479
# 95  0.05 -3.05  0.420486
# 98  0.05 -3.02  0.420495
# 94  0.05 -3.06  0.420508
